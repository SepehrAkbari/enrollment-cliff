# %%
import pandas

df = pandas.read_excel("Bita_college_closure/college_closures.xlsx")
df
# Out:
#                                             name       UID  \
# 0                   Alderson Broaddus University  237118.0
# 1   Alliance University (Formerly Nyack College)  194161.0
# 2             American University of Puerto Rico  241100.0
# 3                                Ancilla College  497833.0
# 4                                 Becker College  164720.0
# ..                                           ...       ...
# 74                                           NaN       NaN
# 75                                           NaN       NaN
# 76                                           NaN       NaN
# 77                                           NaN       NaN
# 78                                           NaN       NaN
#
#                              closure year  established              address  \
# 0                                    2023       1871.0  101 College Hill Rd
# 1                                    2023       1882.0      2 Washington St
# ...

# %%
UIDs= df["UID"].dropna()
UIDs = UIDs.astype(int)
uids = []
for uid in UIDs:
    print(str(uid), end=", ")
    uids.append(str(uid))

len(uids)
# Out:
# 237118, 194161, 241100, 497833, 164720, 183822, 201371, 211352, 238430, 189848, 201751, 459417, 190248, 172440, 177418, 367884, 239743, 115728, 465812, 151111, 153621, 132879, 101541, 146667, 146676, 146825, 182917, 230940, 220701, 118541, 192925, 118888, 209287, 204468, 237640, 209603, 442356, 167455, 219295, 486433, 214564, 122454, 182458, 148876, 19580901, 179256, 195234, 215132, 240365, 240277, 240453, 240453, 131098, 125897, 149763, 100937, 207935, 197230, 165644, 176770, 240462, 164085,
# 62
